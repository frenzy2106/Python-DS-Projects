# %% [markdown]
# # Churn Prediction using Gradient Boosting Methods

# %% [markdown]
# The task is to identify customers likely to churn balances in the next quarter by atleast 50% vis-a-vis current quarter. We have the customers information such as age, gender, demographics along with their assets, liabilities and transactions with the bank.

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import lightgbm as lgb
from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import StratifiedKFold, cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
# Read train and test data
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
test['Responders'] = np.nan

# %%
# Combine data for performing Feature Engineering
combin = pd.concat([train,test])
combin.replace('Y', 1, inplace = True)
combin.replace('N', 0, inplace = True)

# %%
# Replacing all nans in time series variables by zero
combin.iloc[:,11:11 + 39 * 6].fillna(0,inplace = True)

# %%
d_c_cols = [col for col in combin.iloc[:,11:50].columns]
d_c_cols = [element[:-1] for element in d_c_cols]

# Create new features from the last 3 months using some measures including max, min, mean and standard deviation
for col in d_c_cols:
    col2 = [column for column in combin.columns if col in column]
    combin['Last_3_month_average_' + str(col)]  = combin[col2].mean(axis = 1)
    combin['Last_3_month_max_' + str(col)]  = combin[col2].max(axis = 1)
    combin['Last_3_month_min_' + str(col)]  = combin[col2].min(axis = 1)
    combin['Last_3_month_std_' + str(col)]  = combin[col2].std(axis = 1)

# %%
# Drop in Debit amount as a percentage of the avg monthly balance
for i in np.arange(1,6):
    combin['custinit_DR_amt_Drop_Build_'+ str(i)] = (combin['custinit_DR_amt_prev' + str(i+1)] - combin['custinit_DR_amt_prev' + str(i)])/(1 + combin['BAL_prev' + str(i)])

# %%
# Difference between end of month balance and average balance of each month as percentage of avg balance
for i in np.arange(1,7):
    combin['EOP_BAL_DIFF_prev' + str(i)] = (combin['EOP_prev' + str(i)] - combin['BAL_prev'+ str(i)])/combin['BAL_prev' + str(i)]

# Standard Deviation for the above generated feature
eop_bal_cols = [col for col in combin.columns if 'EOP_BAL_DIFF' in col]
combin['STD_EOP_BAL_DIFF_prev'] = combin[eop_bal_cols].std(axis = 1)

# Measures generated from percentage change in credit amount for each pair of consecutive months
cr_amb_drop_cols = ['CR_AMB_Drop_Build_1','CR_AMB_Drop_Build_2','CR_AMB_Drop_Build_3']
combin['Mean_CR_AMB_Drop_Build'] = combin[cr_amb_drop_cols].mean(axis = 1)
combin['STD_CR_AMB_Drop_Build'] = combin[cr_amb_drop_cols].std(axis = 1)
combin['MIN_CR_AMB_Drop_Build'] = combin[cr_amb_drop_cols].min(axis = 1)
combin['Weighted_Sum_CR_AMB_Drop_Build'] = 1 * (combin['CR_AMB_Drop_Build_1'] < 0) + 0.8 * (combin['CR_AMB_Drop_Build_2'] < 0) + 0.6 * (combin['CR_AMB_Drop_Build_3'] < 0) + 0.4 *(combin['CR_AMB_Drop_Build_4'] < 0) + 0.2 * (combin['CR_AMB_Drop_Build_5'] < 0)


i_cnr_prev = ['I_CNR_PrevQ1','I_CNR_PrevQ2']
i_aqb_prev = ['I_AQB_PrevQ1','I_AQB_PrevQ1']

# Change in quarterly average balance
combin['I_AQB_CHANGE'] = (combin['I_AQB_PrevQ1'] - combin['I_AQB_PrevQ2'])
combin['I_NRV_CHANGE'] = (combin['I_NRV_PrevQ1'] - combin['I_NRV_PrevQ2'])

# Average of quarterly customer net revenue and quarterly balance
combin['Mean_I_CNR_PrevQ'] = combin[i_cnr_prev].mean(axis = 1)
combin['Mean_I_AQB_PrevQ'] = combin[i_aqb_prev].mean(axis = 1)

# Sum of average debit and credit transactions in the past 3 months 
combin['Total_Count_txn'] = (combin['Last_3_month_average_count_C_prev'] + combin['Last_3_month_average_count_D_prev'])

# Percentage of transactions via each mode - branch, atm and mobile banking
combin['percent_txn_branch'] = (combin['Last_3_month_average_COUNT_BRANCH_C_prev'] + combin['Last_3_month_average_COUNT_BRANCH_D_prev'])/combin['Total_Count_txn']
combin['percent_txn_atm'] = (combin['Last_3_month_average_COUNT_ATM_C_prev'] + combin['Last_3_month_average_COUNT_ATM_D_prev'])/combin['Total_Count_txn']
combin['percent_txn_phn_mob'] = (combin['Last_3_month_average_COUNT_IB_C_prev'] + combin['Last_3_month_average_COUNT_IB_D_prev'] + combin['Last_3_month_average_COUNT_MB_C_prev'] + combin['Last_3_month_average_COUNT_MB_D_prev'])/combin['Total_Count_txn']
percent_change_cols = ['Percent_Change_in_Credits', 'Percent_Change_in_FT_Bank', 'Percent_Change_in_FT_outside', 'Percent_Change_in_Self_Txn', 'Percent_Change_in_Big_Expenses']
# Median percentage change for all modes of transaction
combin['Median_Percent_change'] = combin[percent_change_cols].median(axis = 1)

# %%
# Label encoding some categorical features
dict_hnw = {'3_Classic': 3, '2_Preferred': 2, '1_Imperia':1}
combin.replace({"HNW_CATEGORY": dict_hnw}, inplace=True)

dict_fw = {'HIGH': 3, 'MEDIUM': 2, 'LOW':1}
combin.replace({"FINAL_WORTH_prev1": dict_fw}, inplace=True)

dict_eng = {'HIGH': 3, 'MEDIUM': 2, 'LOW':1, 'NO':-1}
combin.replace({'ENGAGEMENT_TAG_prev1': dict_eng}, inplace=True)

dict_rbi_ca = {'METROPOLITAN': 3, 'URBAN': 2, 'SEMI-URBAN':1, 'RURAL':0}
combin.replace({'RBI_Class_Audit': dict_rbi_ca}, inplace=True)

dict_billpay = {'A_MISSING': -9999, 'B_1':1, 'C_2':2, 'D_3':3}
combin.replace({'Billpay_Active_PrevQ1_N': dict_billpay}, inplace=True)
combin.replace({'Billpay_Reg_ason_Prev1_N': dict_billpay}, inplace=True)
combin.replace({'Charges_cnt_PrevQ1_N': dict_billpay}, inplace=True)
combin.replace({'FRX_PrevQ1_N': dict_billpay}, inplace=True)

dict_gender = {'Male': 1, 'Female':0, 'Missin':-1}
combin.replace({'gender_bin': dict_gender}, inplace = True)

# %%
# Convert city variable wrt degree of number of customers
combin['new_city'] = combin['city']
counts = combin.city.value_counts()
combin.new_city[combin['new_city'].isin(counts[counts > 9000].index)] = 3
combin.new_city[combin['new_city'].isin(counts[counts < 9000].index) & combin['new_city'].isin(counts[counts >= 3500].index)] = 2
combin.new_city[combin['new_city'].isin(counts[counts < 3500].index) & combin['new_city'].isin(counts[counts >= 1000].index)] = 1
combin.new_city[combin['new_city'].isin(counts[counts < 1000].index)] = 0

combin['zip'] = combin['zip'].astype('object')
combin['zip_first_3'] = combin['zip'].str[:3]

# %%
# Convert occupation to one hot encoded features
combin = pd.concat([combin,pd.get_dummies(combin['OCCUP_ALL_NEW'],prefix = str('OCCUP_ALL_NEW'),prefix_sep='_')],axis = 1)

# %%
# Create derived features from the loan specific information
prem_cols = [col for col in combin.columns if 'PREM_CLOSED' in col]

combin['any_prematurely_closed_loans'] = combin[prem_cols].sum(axis = 1)
loan_closed_cols = ['AGRI_Closed_PrevQ1', 'AL_CNC_Closed_PrevQ1', 'AL_Closed_PrevQ1', 'BL_Closed_PrevQ1', 'CC_CLOSED_PREVQ1', 'CE_Closed_PrevQ1', 'CV_Closed_PrevQ1', 'EDU_Closed_PrevQ1', 'GL_Closed_PrevQ1', 'OTHER_LOANS_Closed_PrevQ1', 'PL_Closed_PrevQ1', 'RD_CLOSED_PREVQ1', 'FD_CLOSED_PREVQ1', 'TL_Closed_PrevQ1', 'TWL_Closed_PrevQ1', 'DEMAT_CLOSED_PREV1YR', 'SEC_ACC_CLOSED_PREV1YR' ]
combin['any_closed'] = combin[loan_closed_cols].max(axis = 1)

live_loan_cols = [col for col in combin.columns if 'LIVE' in col]
combin['any_live_loans'] = combin[live_loan_cols].max(axis = 1)

# %%
# Replace all remaining nans with a large negative value
combin.fillna(-9999,inplace = True)
combin.replace('>', -9999, inplace = True)

dt_cols = ['Req_Resolved_PrevQ1', 'Query_Resolved_PrevQ1', 'Complaint_Resolved_PrevQ1']
for i in dt_cols:
    combin[i] = pd.to_numeric(combin[i], errors='coerce')
combin.drop(['Responders','UCIC_ID','zip','city','OCCUP_ALL_NEW'],axis = 1,inplace=True)

# %%
test_new = combin.iloc[300000:,:]
train_new = combin.iloc[0:300000,:]
y_all = train.Responders

# %%
# Remove 0 variance features
threshold = 0
train_new = train_new.drop(train_new.std()[train_new.std() == threshold].index.values, axis=1)
test_new = test_new[train_new.columns]

# %%
# Model for choosing high performing features
bst_lgb_2 = lgb.LGBMClassifier(learning_rate=0.1, colsample_bytree=0.8, max_depth=9, boosting_type='gbdt', objective='binary',
                               num_leaves=255,
                               n_estimators=300,
                               n_jobs=8, seed = 99)
bst_lgb_2.fit(train_new,y_all)

# Feature selection using the above model to build a less complex yet well performing model
from sklearn.feature_selection import SelectFromModel
sfm = SelectFromModel(bst_lgb_2, threshold='median')
sfm.fit(train_new,y_all)
z = sfm.get_support(indices=False)
zz = pd.DataFrame({'Feature':train_new.columns.values, 'ret': z})
cols = np.array(zz.loc[zz.ret == 1,'Feature'])
train_new = pd.DataFrame(sfm.transform(train_new),columns=cols)
test_new = pd.DataFrame(sfm.transform(test_new),columns=cols)

# %%
kfold = 10
nrounds = 5000
X = train_new.values
y = y_all.values
features = train_new.columns
probs = 0
y_test_pred_xgb = 0
y_valid_pred_xgb = train['UCIC_ID'].to_frame()
y_valid_pred_xgb['xgb'] = 0
y_test_pred_lgb = 0
y_valid_pred_lgb = train['UCIC_ID'].to_frame()
y_valid_pred_lgb['lgb'] = 0

# %% [markdown]
# ## XGBoost Averaged over 10 folds

# %%
sub_xgb=test['UCIC_ID'].to_frame()
sub_xgb['Responders']=0


params = {}
params['objective'] = 'binary:logistic'
params['eta'] = 0.01
params['booster'] = 'gbtree'
params['silent'] = True
params['max_depth'] = 6
params['subsample'] = 0.8
params['colsample_bytree'] = 0.8
params['tree_method'] = 'gpu_hist'
params['eval_metric'] = 'auc'
params['gamma'] = 0.05
params['min_child_weight'] = 7

# Take average of different xgboost models for better generalization

skf = StratifiedKFold(n_splits=kfold, random_state=0, shuffle=True)
np.random.seed(0)

# Using varied models for better generalization
for i, (train_index, test_index) in enumerate(skf.split(X, y)):
    if i <= 3:
        params['max_depth'] = 6
    elif i > 3 and i <= 6:
        params['max_depth'] = 7
    else:
        params['max_depth'] = 8
    print(' xgb kfold: {}  of  {} : '.format(i+1, kfold))
    X_train, X_valid = X[train_index], X[test_index]
    y_train, y_valid = y[train_index], y[test_index]
    d_train = xgb.DMatrix(X_train, y_train)
    d_valid = xgb.DMatrix(X_valid, y_valid)
    watchlist = [(d_train, 'train'), (d_valid, 'valid')]
    xgb_model = xgb.train(params, d_train, nrounds, watchlist, early_stopping_rounds=100,
                          maximize=True, verbose_eval=100)
    
    # Generate validation predictions for this fold
    pred = xgb_model.predict(xgb.DMatrix(X_valid))
    y_valid_pred_xgb.iloc[test_index,1] = pred
    
    probs = xgb_model.predict(xgb.DMatrix(test_new[features].values), 
                        ntree_limit=xgb_model.best_ntree_limit+50)
    y_test_pred_xgb += np.log(probs/(1-probs))
    y_test_pred_xgb /= kfold  # Average test set predictions
    y_test_pred_xgb =  1  /  ( 1 + np.exp(-y_test_pred_xgb) )
    
sub_xgb['Responders'] = y_test_pred_xgb
sub_xgb.to_csv('xgb_tuned_averaged.csv', index=False, float_format='%.5f')
# Out:
#  xgb kfold: 1  of  10 :
# [0]	train-auc:0.836975	valid-auc:0.837246
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.857942	valid-auc:0.856473
# [200]	train-auc:0.863421	valid-auc:0.861196
# [300]	train-auc:0.868463	valid-auc:0.865093
# [400]	train-auc:0.873885	valid-auc:0.868979
# [500]	train-auc:0.877869	valid-auc:0.871159
# [600]	train-auc:0.880687	valid-auc:0.872623
# [700]	train-auc:0.882992	valid-auc:0.873501
# [800]	train-auc:0.885042	valid-auc:0.873988
# [900]	train-auc:0.886828	valid-auc:0.874408
# [1000]	train-auc:0.888504	valid-auc:0.874797
# [1100]	train-auc:0.889992	valid-auc:0.875066
# [1200]	train-auc:0.891399	valid-auc:0.875232
# [1300]	train-auc:0.892703	valid-auc:0.875394
# [1400]	train-auc:0.89398	valid-auc:0.875564
# [1500]	train-auc:0.895191	valid-auc:0.87568
# [1600]	train-auc:0.896456	valid-auc:0.875782
# [1700]	train-auc:0.897663	valid-auc:0.87586
# [1800]	train-auc:0.898861	valid-auc:0.875933
# [1900]	train-auc:0.900019	valid-auc:0.875966
# [2000]	train-auc:0.901187	valid-auc:0.876073
# [2100]	train-auc:0.902225	valid-auc:0.876112
# [2200]	train-auc:0.90337	valid-auc:0.876174
# [2300]	train-auc:0.904503	valid-auc:0.876235
# [2400]	train-auc:0.905524	valid-auc:0.876294
# [2500]	train-auc:0.906546	valid-auc:0.876283
# Stopping. Best iteration:
# [2407]	train-auc:0.905591	valid-auc:0.876295
#
#  xgb kfold: 2  of  10 :
# [0]	train-auc:0.837543	valid-auc:0.828289
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.858571	valid-auc:0.849242
# [200]	train-auc:0.86386	valid-auc:0.853633
# [300]	train-auc:0.869271	valid-auc:0.857539
# [400]	train-auc:0.874552	valid-auc:0.86124
# [500]	train-auc:0.878418	valid-auc:0.863816
# [600]	train-auc:0.881211	valid-auc:0.865273
# [700]	train-auc:0.883583	valid-auc:0.866291
# [800]	train-auc:0.88561	valid-auc:0.866874
# [900]	train-auc:0.887404	valid-auc:0.867329
# [1000]	train-auc:0.88899	valid-auc:0.867604
# [1100]	train-auc:0.890505	valid-auc:0.867911
# [1200]	train-auc:0.891942	valid-auc:0.86812
# [1300]	train-auc:0.89325	valid-auc:0.868283
# [1400]	train-auc:0.894558	valid-auc:0.868472
# [1500]	train-auc:0.895763	valid-auc:0.868557
# [1600]	train-auc:0.896977	valid-auc:0.868659
# [1700]	train-auc:0.898276	valid-auc:0.868714
# [1800]	train-auc:0.899469	valid-auc:0.868852
# [1900]	train-auc:0.900591	valid-auc:0.868882
# [2000]	train-auc:0.901714	valid-auc:0.868972
# [2100]	train-auc:0.902826	valid-auc:0.869054
# [2200]	train-auc:0.903935	valid-auc:0.86911
# [2300]	train-auc:0.90506	valid-auc:0.869206
# [2400]	train-auc:0.906099	valid-auc:0.869241
# [2500]	train-auc:0.907166	valid-auc:0.869337
# [2600]	train-auc:0.908184	valid-auc:0.869358
# [2700]	train-auc:0.909173	valid-auc:0.869397
# [2800]	train-auc:0.910203	valid-auc:0.869424
# [2900]	train-auc:0.911181	valid-auc:0.869451
# [3000]	train-auc:0.912172	valid-auc:0.869441
# [3100]	train-auc:0.913149	valid-auc:0.869486
# [3200]	train-auc:0.91412	valid-auc:0.869531
# [3300]	train-auc:0.915122	valid-auc:0.869527
# Stopping. Best iteration:
# [3243]	train-auc:0.914569	valid-auc:0.869572
#
#  xgb kfold: 3  of  10 :
# [0]	train-auc:0.835571	valid-auc:0.826042
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.858824	valid-auc:0.850527
# [200]	train-auc:0.864271	valid-auc:0.854666
# [300]	train-auc:0.869365	valid-auc:0.858026
# [400]	train-auc:0.874746	valid-auc:0.862007
# [500]	train-auc:0.878562	valid-auc:0.86426
# [600]	train-auc:0.881465	valid-auc:0.865709
# [700]	train-auc:0.883718	valid-auc:0.866435
# [800]	train-auc:0.885683	valid-auc:0.867039
# [900]	train-auc:0.887434	valid-auc:0.86737
# [1000]	train-auc:0.888986	valid-auc:0.867694
# [1100]	train-auc:0.890466	valid-auc:0.86795
# [1200]	train-auc:0.891901	valid-auc:0.868145
# [1300]	train-auc:0.893222	valid-auc:0.868337
# [1400]	train-auc:0.894499	valid-auc:0.86851
# [1500]	train-auc:0.895792	valid-auc:0.868615
# [1600]	train-auc:0.897008	valid-auc:0.868801
# [1700]	train-auc:0.898212	valid-auc:0.868878
# [1800]	train-auc:0.899326	valid-auc:0.869021
# [1900]	train-auc:0.900514	valid-auc:0.869113
# [2000]	train-auc:0.901668	valid-auc:0.869144
# [2100]	train-auc:0.902761	valid-auc:0.869248
# [2200]	train-auc:0.903908	valid-auc:0.86933
# [2300]	train-auc:0.904969	valid-auc:0.869396
# [2400]	train-auc:0.906002	valid-auc:0.86947
# [2500]	train-auc:0.907056	valid-auc:0.869483
# [2600]	train-auc:0.908135	valid-auc:0.869549
# [2700]	train-auc:0.909125	valid-auc:0.869554
# [2800]	train-auc:0.910091	valid-auc:0.869608
# Stopping. Best iteration:
# [2780]	train-auc:0.909914	valid-auc:0.869619
#
#  xgb kfold: 4  of  10 :
# [0]	train-auc:0.836156	valid-auc:0.835448
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.857971	valid-auc:0.856898
# [200]	train-auc:0.863551	valid-auc:0.86118
# [300]	train-auc:0.868981	valid-auc:0.8649
# [400]	train-auc:0.873999	valid-auc:0.868356
# [500]	train-auc:0.877793	valid-auc:0.87052
# [600]	train-auc:0.880721	valid-auc:0.871787
# [700]	train-auc:0.883001	valid-auc:0.872496
# [800]	train-auc:0.884959	valid-auc:0.873017
# [900]	train-auc:0.886796	valid-auc:0.873418
# [1000]	train-auc:0.888383	valid-auc:0.873737
# [1100]	train-auc:0.889857	valid-auc:0.873946
# [1200]	train-auc:0.89131	valid-auc:0.874103
# [1300]	train-auc:0.892656	valid-auc:0.874287
# [1400]	train-auc:0.89402	valid-auc:0.874481
# [1500]	train-auc:0.895295	valid-auc:0.874603
# [1600]	train-auc:0.896475	valid-auc:0.874673
# [1700]	train-auc:0.897743	valid-auc:0.874773
# [1800]	train-auc:0.89892	valid-auc:0.874904
# [1900]	train-auc:0.900049	valid-auc:0.874948
# [2000]	train-auc:0.901273	valid-auc:0.875011
# [2100]	train-auc:0.902398	valid-auc:0.875054
# [2200]	train-auc:0.90356	valid-auc:0.875118
# [2300]	train-auc:0.904709	valid-auc:0.875179
# [2400]	train-auc:0.905736	valid-auc:0.875237
# [2500]	train-auc:0.906822	valid-auc:0.875303
# [2600]	train-auc:0.907868	valid-auc:0.875363
# [2700]	train-auc:0.908879	valid-auc:0.875368
# [2800]	train-auc:0.909836	valid-auc:0.875393
# [2900]	train-auc:0.910807	valid-auc:0.875381
# Stopping. Best iteration:
# [2838]	train-auc:0.910208	valid-auc:0.87544
#
#  xgb kfold: 5  of  10 :
# [0]	train-auc:0.843536	valid-auc:0.84039
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.862949	valid-auc:0.858345
# [200]	train-auc:0.869241	valid-auc:0.862637
# [300]	train-auc:0.875659	valid-auc:0.86651
# [400]	train-auc:0.881682	valid-auc:0.869336
# [500]	train-auc:0.886466	valid-auc:0.871258
# [600]	train-auc:0.890102	valid-auc:0.872251
# [700]	train-auc:0.892991	valid-auc:0.87284
# [800]	train-auc:0.895528	valid-auc:0.87312
# [900]	train-auc:0.897698	valid-auc:0.873357
# [1000]	train-auc:0.89973	valid-auc:0.87345
# [1100]	train-auc:0.901567	valid-auc:0.873577
# [1200]	train-auc:0.903438	valid-auc:0.873671
# [1300]	train-auc:0.90525	valid-auc:0.873736
# [1400]	train-auc:0.907001	valid-auc:0.873754
# Stopping. Best iteration:
# [1352]	train-auc:0.906185	valid-auc:0.873789
#
#  xgb kfold: 6  of  10 :
# [0]	train-auc:0.83992	valid-auc:0.839246
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.862573	valid-auc:0.861301
# [200]	train-auc:0.869039	valid-auc:0.865221
# [300]	train-auc:0.875794	valid-auc:0.868425
# [400]	train-auc:0.881565	valid-auc:0.870926
# [500]	train-auc:0.886378	valid-auc:0.872803
# [600]	train-auc:0.889973	valid-auc:0.873742
# [700]	train-auc:0.892841	valid-auc:0.874231
# [800]	train-auc:0.895404	valid-auc:0.874715
# [900]	train-auc:0.897646	valid-auc:0.874949
# [1000]	train-auc:0.899688	valid-auc:0.87513
# [1100]	train-auc:0.901636	valid-auc:0.875226
# [1200]	train-auc:0.90363	valid-auc:0.875379
# [1300]	train-auc:0.9055	valid-auc:0.875439
# [1400]	train-auc:0.907365	valid-auc:0.875468
# Stopping. Best iteration:
# [1338]	train-auc:0.906243	valid-auc:0.875495
#
#  xgb kfold: 7  of  10 :
# [0]	train-auc:0.843315	valid-auc:0.840324
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.86335	valid-auc:0.858959
# [200]	train-auc:0.869221	valid-auc:0.862474
# [300]	train-auc:0.875836	valid-auc:0.866025
# [400]	train-auc:0.881712	valid-auc:0.868788
# [500]	train-auc:0.886508	valid-auc:0.870609
# [600]	train-auc:0.88994	valid-auc:0.871589
# [700]	train-auc:0.892662	valid-auc:0.872117
# [800]	train-auc:0.895092	valid-auc:0.872525
# [900]	train-auc:0.897404	valid-auc:0.872909
# [1000]	train-auc:0.899424	valid-auc:0.873184
# [1100]	train-auc:0.901351	valid-auc:0.873387
# [1200]	train-auc:0.903265	valid-auc:0.873593
# [1300]	train-auc:0.905114	valid-auc:0.873741
# [1400]	train-auc:0.906841	valid-auc:0.873838
# [1500]	train-auc:0.908584	valid-auc:0.873955
# [1600]	train-auc:0.910172	valid-auc:0.873995
# [1700]	train-auc:0.911888	valid-auc:0.874081
# [1800]	train-auc:0.913523	valid-auc:0.87414
# [1900]	train-auc:0.915036	valid-auc:0.874272
# [2000]	train-auc:0.916599	valid-auc:0.874336
# [2100]	train-auc:0.918123	valid-auc:0.87438
# [2200]	train-auc:0.919635	valid-auc:0.874387
# Stopping. Best iteration:
# [2118]	train-auc:0.918379	valid-auc:0.874406
#
#  xgb kfold: 8  of  10 :
# [0]	train-auc:0.846472	valid-auc:0.838456
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.869331	valid-auc:0.860715
# [200]	train-auc:0.87657	valid-auc:0.86439
# [300]	train-auc:0.883859	valid-auc:0.86738
# [400]	train-auc:0.891305	valid-auc:0.870317
# [500]	train-auc:0.897225	valid-auc:0.872173
# [600]	train-auc:0.901649	valid-auc:0.873074
# [700]	train-auc:0.90525	valid-auc:0.873555
# [800]	train-auc:0.908345	valid-auc:0.873756
# [900]	train-auc:0.911175	valid-auc:0.873996
# [1000]	train-auc:0.913668	valid-auc:0.874137
# [1100]	train-auc:0.916179	valid-auc:0.874283
# [1200]	train-auc:0.918475	valid-auc:0.874268
# Stopping. Best iteration:
# [1148]	train-auc:0.917297	valid-auc:0.874287
#
#  xgb kfold: 9  of  10 :
# [0]	train-auc:0.848146	valid-auc:0.84453
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.869269	valid-auc:0.862481
# [200]	train-auc:0.876386	valid-auc:0.866315
# [300]	train-auc:0.884172	valid-auc:0.869567
# [400]	train-auc:0.891283	valid-auc:0.871426
# [500]	train-auc:0.897283	valid-auc:0.872863
# [600]	train-auc:0.901716	valid-auc:0.873642
# [700]	train-auc:0.905459	valid-auc:0.874019
# [800]	train-auc:0.908711	valid-auc:0.874187
# [900]	train-auc:0.911592	valid-auc:0.874351
# [1000]	train-auc:0.914156	valid-auc:0.874422
# [1100]	train-auc:0.91655	valid-auc:0.874502
# [1200]	train-auc:0.918944	valid-auc:0.874524
# Stopping. Best iteration:
# [1119]	train-auc:0.91703	valid-auc:0.87455
#
#  xgb kfold: 10  of  10 :
# [0]	train-auc:0.848569	valid-auc:0.843754
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.869126	valid-auc:0.861126
# [200]	train-auc:0.876173	valid-auc:0.865276
# [300]	train-auc:0.884169	valid-auc:0.868636
# [400]	train-auc:0.891275	valid-auc:0.871041
# [500]	train-auc:0.897193	valid-auc:0.872597
# [600]	train-auc:0.90165	valid-auc:0.873543
# [700]	train-auc:0.905244	valid-auc:0.873983
# [800]	train-auc:0.908285	valid-auc:0.874236
# [900]	train-auc:0.911178	valid-auc:0.87442
# [1000]	train-auc:0.913798	valid-auc:0.874595
# [1100]	train-auc:0.916238	valid-auc:0.87475
# [1200]	train-auc:0.918554	valid-auc:0.874917
# [1300]	train-auc:0.920775	valid-auc:0.875017
# [1400]	train-auc:0.922933	valid-auc:0.87508
# [1500]	train-auc:0.925104	valid-auc:0.875174
# [1600]	train-auc:0.927337	valid-auc:0.875341
# [1700]	train-auc:0.929409	valid-auc:0.875387
# [1800]	train-auc:0.931325	valid-auc:0.875444
# Stopping. Best iteration:
# [1756]	train-auc:0.930442	valid-auc:0.875458

# %% [markdown]
# ## LightGBM Averaged over 10 folds

# %%
# lgb
kfold = 10
sub_lgb=test['UCIC_ID'].to_frame()
sub_lgb['Responders']=0

params = {'metric': 'auc', 'learning_rate' : 0.01, 'max_depth':9, 'max_bin':20,  'objective': 'binary', 
          'feature_fraction': 0.8,'bagging_fraction':0.9,'bagging_freq':10,  'min_data': 500, 'num_leaves': 255}

skf = StratifiedKFold(n_splits=kfold, random_state=5, shuffle = True)
for i, (train_index, test_index) in enumerate(skf.split(X, y)):

# Using varied models for better generalization
    if i <= 3:
        params['num_leaves'] = 127
        params['max_depth'] = 0
    elif i > 3 and i <= 6:
        params['num_leaves'] = 90
        params['max_depth'] = 0
    else:
        params['max_depth'] = 9
        params['num_leaves'] = 255
    print(' lgb kfold: {}  of  {} : '.format(i+1, kfold))
    X_train, X_eval = X[train_index], X[test_index]
    y_train, y_eval = y[train_index], y[test_index]
    lgb_model = lgb.train(params, lgb.Dataset(X_train, label=y_train), nrounds, 
                  lgb.Dataset(X_eval, label=y_eval), verbose_eval=100, 
                  early_stopping_rounds=100)
    sub_lgb['Responders'] += lgb_model.predict(test_new[features].values, 
                        num_iteration=lgb_model.best_iteration) / (kfold)
sub_lgb.to_csv('lgb_tuned_averaged.csv', index=False, float_format='%.5f')
# Out:
#  lgb kfold: 1  of  10 :
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.863606
# [200]	valid_0's auc: 0.866802
# [300]	valid_0's auc: 0.86935
# [400]	valid_0's auc: 0.871943
# [500]	valid_0's auc: 0.873629
# [600]	valid_0's auc: 0.874646
# [700]	valid_0's auc: 0.875183
# [800]	valid_0's auc: 0.87538
# [900]	valid_0's auc: 0.875656
# [1000]	valid_0's auc: 0.875665
# Early stopping, best iteration is:
# [909]	valid_0's auc: 0.87568
#  lgb kfold: 2  of  10 :
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.855871
# [200]	valid_0's auc: 0.858575
# [300]	valid_0's auc: 0.860949
# [400]	valid_0's auc: 0.863757
# [500]	valid_0's auc: 0.865536
# [600]	valid_0's auc: 0.866619
# [700]	valid_0's auc: 0.867048
# [800]	valid_0's auc: 0.867327
# [900]	valid_0's auc: 0.867547
# [1000]	valid_0's auc: 0.867666
# [1100]	valid_0's auc: 0.867823
# [1200]	valid_0's auc: 0.867923
# [1300]	valid_0's auc: 0.867864
# Early stopping, best iteration is:
# [1212]	valid_0's auc: 0.867935
#  lgb kfold: 3  of  10 :
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.86443
# [200]	valid_0's auc: 0.867261
# [300]	valid_0's auc: 0.869426
# [400]	valid_0's auc: 0.871409
# [500]	valid_0's auc: 0.872638
# [600]	valid_0's auc: 0.873424
# [700]	valid_0's auc: 0.873796
# [800]	valid_0's auc: 0.874057
# [900]	valid_0's auc: 0.874234
# [1000]	valid_0's auc: 0.874316
# Early stopping, best iteration is:
# [930]	valid_0's auc: 0.874363
#  lgb kfold: 4  of  10 :
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.861433
# [200]	valid_0's auc: 0.863908
# [300]	valid_0's auc: 0.866209
# [400]	valid_0's auc: 0.868633
# [500]	valid_0's auc: 0.869784
# [600]	valid_0's auc: 0.870532
# [700]	valid_0's auc: 0.870979
# [800]	valid_0's auc: 0.871349
# [900]	valid_0's auc: 0.871511
# [1000]	valid_0's auc: 0.871663
# [1100]	valid_0's auc: 0.871751
# [1200]	valid_0's auc: 0.871833
# [1300]	valid_0's auc: 0.871824
# Early stopping, best iteration is:
# [1272]	valid_0's auc: 0.871875
#  lgb kfold: 5  of  10 :
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.861476
# [200]	valid_0's auc: 0.864413
# [300]	valid_0's auc: 0.867653
# [400]	valid_0's auc: 0.871207
# [500]	valid_0's auc: 0.873247
# [600]	valid_0's auc: 0.874735
# [700]	valid_0's auc: 0.875635
# [800]	valid_0's auc: 0.876205
# [900]	valid_0's auc: 0.876456
# [1000]	valid_0's auc: 0.876708
# [1100]	valid_0's auc: 0.876938
# [1200]	valid_0's auc: 0.877101
# [1300]	valid_0's auc: 0.877096
# [1400]	valid_0's auc: 0.877268
# [1500]	valid_0's auc: 0.877337
# [1600]	valid_0's auc: 0.877416
# [1700]	valid_0's auc: 0.877421
# Early stopping, best iteration is:
# [1614]	valid_0's auc: 0.877445
#  lgb kfold: 6  of  10 :
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.859612
# [200]	valid_0's auc: 0.862838
# [300]	valid_0's auc: 0.865533
# [400]	valid_0's auc: 0.868663
# [500]	valid_0's auc: 0.87058
# [600]	valid_0's auc: 0.871719
# [700]	valid_0's auc: 0.872355
# [800]	valid_0's auc: 0.872883
# [900]	valid_0's auc: 0.873055
# [1000]	valid_0's auc: 0.873204
# [1100]	valid_0's auc: 0.873278
# [1200]	valid_0's auc: 0.873321
# [1300]	valid_0's auc: 0.873485
# [1400]	valid_0's auc: 0.873546
# [1500]	valid_0's auc: 0.873638
# [1600]	valid_0's auc: 0.873582
# Early stopping, best iteration is:
# [1503]	valid_0's auc: 0.873648
#  lgb kfold: 7  of  10 :
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.854774
# [200]	valid_0's auc: 0.858243
# [300]	valid_0's auc: 0.861846
# [400]	valid_0's auc: 0.864863
# [500]	valid_0's auc: 0.867197
# [600]	valid_0's auc: 0.86844
# [700]	valid_0's auc: 0.869226
# [800]	valid_0's auc: 0.869566
# [900]	valid_0's auc: 0.869941
# [1000]	valid_0's auc: 0.870028
# [1100]	valid_0's auc: 0.87013
# [1200]	valid_0's auc: 0.870223
# [1300]	valid_0's auc: 0.870247
# [1400]	valid_0's auc: 0.870378
# [1500]	valid_0's auc: 0.870455
# [1600]	valid_0's auc: 0.870497
# [1700]	valid_0's auc: 0.870505
# [1800]	valid_0's auc: 0.870601
# [1900]	valid_0's auc: 0.870663
# [2000]	valid_0's auc: 0.870686
# [2100]	valid_0's auc: 0.870675
# [2200]	valid_0's auc: 0.87066
# Early stopping, best iteration is:
# [2146]	valid_0's auc: 0.870731
#  lgb kfold: 8  of  10 :
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.864812
# [200]	valid_0's auc: 0.867507
# [300]	valid_0's auc: 0.870321
# [400]	valid_0's auc: 0.872491
# [500]	valid_0's auc: 0.873777
# [600]	valid_0's auc: 0.874307
# [700]	valid_0's auc: 0.874615
# [800]	valid_0's auc: 0.874808
# [900]	valid_0's auc: 0.874915
# [1000]	valid_0's auc: 0.874978
# [1100]	valid_0's auc: 0.875026
# [1200]	valid_0's auc: 0.875132
# [1300]	valid_0's auc: 0.875104
# Early stopping, best iteration is:
# [1230]	valid_0's auc: 0.875151
#  lgb kfold: 9  of  10 :
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.860099
# [200]	valid_0's auc: 0.863214
# [300]	valid_0's auc: 0.86564
# [400]	valid_0's auc: 0.86822
# [500]	valid_0's auc: 0.869928
# [600]	valid_0's auc: 0.870654
# [700]	valid_0's auc: 0.871118
# [800]	valid_0's auc: 0.871404
# [900]	valid_0's auc: 0.871576
# [1000]	valid_0's auc: 0.871739
# [1100]	valid_0's auc: 0.871868
# [1200]	valid_0's auc: 0.871897
# [1300]	valid_0's auc: 0.871986
# [1400]	valid_0's auc: 0.872031
# [1500]	valid_0's auc: 0.872076
# [1600]	valid_0's auc: 0.872101
# [1700]	valid_0's auc: 0.872148
# [1800]	valid_0's auc: 0.872192
# Early stopping, best iteration is:
# [1743]	valid_0's auc: 0.872212
#  lgb kfold: 10  of  10 :
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.864692
# [200]	valid_0's auc: 0.867606
# [300]	valid_0's auc: 0.870656
# [400]	valid_0's auc: 0.873353
# [500]	valid_0's auc: 0.875271
# [600]	valid_0's auc: 0.876153
# [700]	valid_0's auc: 0.87663
# [800]	valid_0's auc: 0.876893
# [900]	valid_0's auc: 0.877087
# [1000]	valid_0's auc: 0.877226
# [1100]	valid_0's auc: 0.877323
# [1200]	valid_0's auc: 0.877436
# [1300]	valid_0's auc: 0.877438
# [1400]	valid_0's auc: 0.877487
# [1500]	valid_0's auc: 0.877497
# [1600]	valid_0's auc: 0.877495
# [1700]	valid_0's auc: 0.877459
# Early stopping, best iteration is:
# [1615]	valid_0's auc: 0.877518

# %% [markdown]
# ## Ensemble using mean

# %%
# Calculating Normalized rank and making ensemble
xgb_pred = pd.read_csv('xgb_tuned_averaged.csv')
lgb_pred = pd.read_csv('lgb_tuned_averaged.csv')
xgb_pred['rank/length'] = xgb_pred['Responders'].rank(ascending = 1)/xgb_pred.shape[0]
lgb_pred['rank/length'] = lgb_pred['Responders'].rank(ascending = 1)/lgb_pred.shape[0]
sub = pd.DataFrame({'UCIC_ID': test.UCIC_ID, 'Responders':0.45 * xgb_pred['rank/length'] + 0.55 * lgb_pred['rank/length']})
sub.to_csv('sub_ens_rank_norm_xgb_lgb.csv',index=False,float_format='%.6f')

# %% [markdown]
# ## Rough Code for necessary testing and surgery

# %%
"""
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=20, n_estimators=150, n_jobs=8, verbose=3)
clf.fit(train_new,y_all)
rf_feature = clf.feature_importances_
feat_imp = pd.DataFrame({'Feature':train_new.columns.values, 'Importance': rf_feature})
feat_imp.sort_values(by='Importance',ascending=False)
"""

# %%
"""
import matplotlib.pyplot as plt
plt.plot(rf_feature)
plt.show()
"""

# %%
#feat_imp.sort_values(by='Importance',ascending=False)

# %%
"""
xg_train = xgb.DMatrix(train_new, y_all)
xg_test = xgb.DMatrix(test_new)
params = {}
params['objective'] = 'binary:logistic'
params['eta'] = 0.1
params['booster'] = 'gbtree'
params['silent'] = True
params['max_depth'] = 6
params['subsample'] = 0.8
params['colsample_bytree'] = 0.8
params['tree_method'] = 'gpu_hist'
params['eval_metric'] = 'auc'
params['gamma'] = 0.05
params['min_child_weight'] = 7
"""

# %%
# Defining the lift metric
"""
def lift(y, pred):
    l = np.asarray(np.c_[y, pred, np.arange(len(y))], dtype=np.float)
    l = l[np.lexsort((l[:,2], -1*l[:,1]))]
    first_decile = round(0.2 * len(y))
    ls = l[0:first_decile,0].sum()/l[:,0].sum()
    return ls

def lift_xgb(pred, y):
    y = y.get_label()
    return 'max_lift', lift(y, pred)
"""

# %%
#cv_results = xgb.cv(params,xg_train,5000,nfold=5,stratified=True,maximize=True,early_stopping_rounds=25,verbose_eval=True,show_stdv=False)

# %%
# Grid Search for XGBoost
"""
from sklearn.model_selection import GridSearchCV
xgb_mod = xgb.XGBClassifier(
        n_estimators=185,
        learning_rate=0.1,
        #tree_method = 'gpu_hist',
        subsample = 0.9,
        colsample_bytree = 0.9,
        max_depth = 6,
        min_child_weight = 7,
        n_jobs=8,
        gamma = 0.05)
clf = GridSearchCV(xgb_mod,{#'max_depth':[6,7,8,9],
                            #'min_child_weight':[6]   
                             #'gamma': [0,0.1,0.2,0.3,0.4]
                              'subsample': [0.9,1],
                              'colsample_bytree': [0.9,1] 
                               }, 
                                verbose=3,
                                scoring='roc_auc')

clf.fit(train_new, y_all)
clf.grid_scores_, clf.best_score_, clf.best_params_
"""

# %%
#d_train = lgb.Dataset(train_new, label=y_all)
#params = {}
"""
params = {'learning_rate': 0.01, 
          'max_depth': 9, 
          'boosting': 'gbdt', 
          'objective': 'binary', 
          'metric': 'auc',
          'num_leaf': 255,
          'is_training_metric': False, 
          'colsample_bytree': '0.8',
          'seed': 99,
          #'scale_pos_weight': 2,
          #'min_child_weight': 0.002
         }
"""
#params = {'metric': 'auc', 'learning_rate' : 0.01, 'max_depth':9, 'max_bin':20,  'objective': 'binary', 
#          'feature_fraction': 0.8,'bagging_fraction':0.9,'bagging_freq':10,  'min_data': 500}
#lgb.cv()

# %%
"""
lgb_cv_results = lgb.cv(params, train_set=d_train, num_boost_round= 5000, 
       nfold = 5, stratified=True, early_stopping_rounds=100, seed = 99, verbose_eval = True,
       show_stdv = False)
"""

# %%
#bst_lgb = lgb.train(params,d_train,1200)
"""
bst_lgb_2 = lgb.LGBMClassifier(learning_rate=0.01, colsample_bytree=0.8, max_depth=9, boosting_type='gbdt', objective='binary',
                               num_leaves=255,
                               n_estimators=1200,
                               n_jobs=8, seed = 99)
bst_lgb_2.fit(train_new,y_all)
"""

# %%
"""
#bst_lgb = lgb.train(params,d_train,2917)
#lgb_pred = bst_lgb.predict(test_new)
#sub = pd.DataFrame({'UCIC_ID': test.UCIC_ID, 'Responders': lgb_pred})
#sub.to_csv('lgb_baseline_10_8732.csv', index = False, float_format = '%.5f')
from lightgbm import plot_importance
import matplotlib.pyplot as plt
plot_importance(bst_lgb,max_num_features=30,figsize=(20,20),grid=False)
plt.show()
"""
